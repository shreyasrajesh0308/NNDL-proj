# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyasrajesh0308/NNDL-proj/blob/main/CNN%2BLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Model Paper:

# %% [markdown]
# ### Load Data
#
# Load preprocessed data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from matplotlib import pyplot as plt
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

# %%
X_test = np.load("/content/drive/MyDrive/project_data/X_test.npy")
y_test = np.load("/content/drive/MyDrive/project_data/y_test.npy")
person_train_valid = np.load("/content/drive/MyDrive/project_data/person_train_valid.npy")
X_train_valid = np.load("/content/drive/MyDrive/project_data/X_train_valid.npy")
y_train_valid = np.load("/content/drive/MyDrive/project_data/y_train_valid.npy")
person_test = np.load("/content/drive/MyDrive/project_data/person_test.npy")

# %%
print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (443, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %%
print(np.unique(y_train_valid))
print(np.unique(y_test))
# Out:
# [769 770 771 772]
# [769 770 771 772]

# %%
num_classes = 4
y_train_valid = y_train_valid-769
y_test = y_test-769

# %%
def data_prep(X,y,sub_sample,average,noise):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,500)
    X = X[:,:,0:500]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    print('Shape of X after subsampling and concatenating:',total_X.shape)
    return total_X,total_y


X_train_valid_prep,y_train_valid_prep = data_prep(X_train_valid,y_train_valid,2,2,True)
# Out:
# Shape of X after trimming: (2115, 22, 500)
# Shape of X after maxpooling: (2115, 22, 250)
# Shape of X after averaging+noise and concatenating: (4230, 22, 250)
# Shape of X after subsampling and concatenating: (8460, 22, 250)

# %%
def data_prep_test(X,y, sub_sample=2):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,500)
    X = X[:,:,0:500]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    print('Shape of X after maxpooling:',total_X.shape)
    return total_X,total_y


X_test,y_test = data_prep_test(X_test, y_test,2)
# Out:
# Shape of X after trimming: (443, 22, 500)
# Shape of X after maxpooling: (443, 22, 250)

# %%
def spatial_prep(X):
  # new_X = []
  # X = X.tolist()
  X = np.swapaxes(X, 0, 1)

  sh = (X.shape[1],X.shape[2])
  new_X = np.array([[np.zeros(sh), np.zeros(sh), np.zeros(sh), X[0,:,:], np.zeros(sh), np.zeros(sh), np.zeros(sh)],
                [np.zeros(sh), X[1,:,:], X[2,:,:], X[3,:,:], X[4,:,:], X[5,:,:], np.zeros(sh)],
                [X[6,:,:],X[7,:,:],X[8,:,:],X[9,:,:],X[10,:,:],X[11,:,:],X[12,:,:]],
                [np.zeros(sh), X[13,:,:],X[14,:,:],X[15,:,:],X[16,:,:],X[17,:,:], np.zeros(sh)],
                [np.zeros(sh), np.zeros(sh), X[18,:,:],X[19,:,:],X[20,:,:], np.zeros(sh), np.zeros(sh)],
                [np.zeros(sh), np.zeros(sh), np.zeros(sh), X[21,:,:], np.zeros(sh), np.zeros(sh), np.zeros(sh)]])

  # for x_seq in X:
  #   n = len(X)
  #   # new_seq_X = np.array([np.array([np.zeros(n), np.zeros(n), np.zeros(n), np.array(x_seq[0]), np.zeros(n), np.zeros(n), np.zeros(n)]),
  #   #              np.array([np.zeros(n), np.array(x_seq[1]), np.array(x_seq[2]), np.array(x_seq[3]), np.array(x_seq[4]), np.array(x_seq[5]), np.zeros(n)]),
  #   #              np.array([np.array(x_seq[6]), np.array(x_seq[7]), np.array(x_seq[8]), np.array(x_seq[9]), np.array(x_seq[10]), np.array(x_seq[11]), np.array(x_seq[12])]),
  #   #              np.array([np.zeros(n), np.array(x_seq[13]), np.array(x_seq[14]), np.array(x_seq[15]), np.array(x_seq[16]), np.array(x_seq[17]), np.zeros(n)]),
  #   #              np.array([np.zeros(n), np.zeros(n), np.array(x_seq[18]), np.array(x_seq[19]), np.array(x_seq[20]), np.zeros(n), np.zeros(n)]),
  #   #              np.array([np.zeros(n), np.zeros(n), np.zeros(n), np.array(x_seq[21]), np.zeros(n), np.zeros(n), np.zeros(n)])])
  #   # new_X.append(new_seq_X)
  #   new_seq_X = np.array([[[0]*n, [0]*n, [0]*n, x_seq[0], [0]*n, [0]*n, [0]*n ],
  #                [[0]*n, x_seq[1], x_seq[2], x_seq[3], x_seq[4], x_seq[5], [0]*n ],
  #                [x_seq[6], x_seq[7], x_seq[8], x_seq[9], x_seq[10], x_seq[11], x_seq[12]],
  #                [[0]*n, x_seq[13], x_seq[14], x_seq[15], x_seq[16], x_seq[17], [0]*n],
  #                [[0]*n, [0]*n, x_seq[18], x_seq[19], x_seq[20], [0]*n, [0]*n],
  #                [[0]*n, [0]*n, [0]*n, x_seq[21], [0]*n, [0]*n, [0]*n]])
  #   new_X.append(new_seq_X)

  # new_X = np.array(new_X)
  new_X = np.swapaxes(new_X, 0,2)
  new_X = np.swapaxes(new_X, 1,2)
  return new_X

# %%
X_spatial_prep = spatial_prep(X_train_valid_prep)

# %%
X_spatial_test = spatial_prep(X_test)

# %%
print(X_spatial_prep.shape, X_spatial_test.shape)
# Out:
# (8460, 6, 7, 250) (443, 6, 7, 250)

# %%
y_train_valid_prep = keras.utils.to_categorical(y_train_valid_prep, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
print(X_train_valid_prep.shape,y_train_valid_prep.shape, X_spatial_prep.shape, X_spatial_test.shape)
print(X_test.shape, y_test.shape)
# Out:
# (8460, 22, 250) (8460, 4) (8460, 6, 7, 250) (443, 6, 7, 250)
# (443, 22, 250) (443, 4)

# %%
X_spatial_prep  = np.swapaxes(X_spatial_prep , 1,3)
X_spatial_prep = np.swapaxes(X_spatial_prep , 2,3)
X_spatial_test  = np.swapaxes(X_spatial_test , 1,3)
X_spatial_test = np.swapaxes(X_spatial_test , 2,3)

# %%
X_spatial_prep = X_spatial_prep.reshape(*X_spatial_prep.shape, 1)
X_spatial_test = X_spatial_test.reshape(*X_spatial_test.shape, 1)

# %%
print(X_train_valid_prep.shape,y_train_valid_prep.shape, X_spatial_prep.shape, X_spatial_test.shape)
print(X_test.shape, y_test.shape)
# Out:
# (8460, 22, 250) (8460, 4) (8460, 250, 6, 7, 1) (443, 250, 6, 7, 1)
# (443, 22, 250) (443, 4)

# %% [markdown]
# ## CNN + GRU model with all subjects

# %%
from keras.layers import Conv2D, BatchNormalization, Activation, Flatten, Dense, Dropout, LSTM, Input, TimeDistributed, Permute, Reshape, MaxPooling2D, GRU
from keras import initializers, Model, optimizers, callbacks
from keras import Sequential
from keras import backend as K
from keras.models import load_model
from keras.callbacks import Callback
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score

# %%
## Complicated Model - the same as Zhang`s
# input_shape = (250, 6, 7, 1)
# lecun = initializers.lecun_normal(seed=42)

# # TimeDistributed Wrapper
# def timeDist(layer, prev_layer, name):
#     return TimeDistributed(layer, name=name)(prev_layer)
    
# # Input layer
# inputs = Input(shape=input_shape)

# # Convolutional layers block
# x = timeDist(Conv2D(32, (3,3), padding='same', 
#                     data_format='channels_last', kernel_initializer=lecun), inputs, name='CNN1')
# x = BatchNormalization(name='batch1')(x)
# x = Activation('elu', name='act1')(x)
# x = timeDist(Conv2D(64, (3,3), padding='same', data_format='channels_last', kernel_initializer=lecun), x, name='CNN2')
# x = BatchNormalization(name='batch2')(x)
# x = Activation('elu', name='act2')(x)
# x = timeDist(Conv2D(128, (3,3), padding='same', data_format='channels_last', kernel_initializer=lecun), x, name='CNN3')
# x = BatchNormalization(name='batch3')(x)
# x = Activation('elu', name='act3')(x)
# x = timeDist(Flatten(), x, name='flatten')

# # Fully connected layer block
# y = Dense(64, kernel_initializer=lecun, name='FC')(x)
# y = Dropout(0.5, name='dropout1')(y)
# y = BatchNormalization(name='batch4')(y)
# y = Activation(activation='elu')(y)

# # Recurrent layers block
# #z = LSTM(64, kernel_initializer=lecun, return_sequences=True, name='LSTM1')(y)
# z = LSTM(64, kernel_initializer=lecun, name='LSTM2')(y)

# # Fully connected layer block
# h = Dense(128, kernel_initializer=lecun, activation='relu', name='FC2')(z)
# h = Dropout(0.5, name='dropout2')(h)

# # Output layer
# outputs = Dense(4, activation='softmax')(h)

# # Model compile
# model = Model(inputs=inputs, outputs=outputs)
# model.summary()

lecun = initializers.lecun_normal(seed=42)

model = Sequential()

model.add(Permute((2, 1), input_shape=(22, 250)))
model.add(Reshape((250, 22, 1)))

model.add(Conv2D(filters=25, kernel_size=(10,1), kernel_initializer = lecun, strides=1, data_format="channels_last"))
model.add(Conv2D(filters=25, kernel_size=(1,22), kernel_initializer = lecun ))
model.add(BatchNormalization())
model.add(Activation(activation = 'elu'))
model.add(MaxPooling2D(pool_size = (3,1), strides = (3,1)))
model.add(Dropout(0.5))

# Conv Pool Block 2
model.add(Conv2D(filters = 50, kernel_size = (10,1), activation = 'elu', kernel_initializer = lecun))
model.add(BatchNormalization())
model.add(Activation(activation = 'elu'))
model.add(MaxPooling2D(pool_size = (3,1), strides = (3,1)))
model.add(Dropout(0.5))

model.add(Permute((1, 3, 2)))
model.add(Reshape((23, 50)))

# LSTM layers
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32, return_sequences=True))
#model.add(LSTM(32, return_sequences=True))
#model.add(LSTM(32, return_sequences=True))

# Dense layers
model.add(Flatten())
model.add(Dense(units=4, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  permute (Permute)           (None, 250, 22)           0
#
#  reshape (Reshape)           (None, 250, 22, 1)        0
#
#  conv2d (Conv2D)             (None, 241, 22, 25)       275
#
#  conv2d_1 (Conv2D)           (None, 241, 1, 25)        13775
#
#  batch_normalization (BatchN  (None, 241, 1, 25)       100
#  ormalization)
#
#  activation (Activation)     (None, 241, 1, 25)        0
#
#  max_pooling2d (MaxPooling2D  (None, 80, 1, 25)        0
#  )
#
#  dropout (Dropout)           (None, 80, 1, 25)         0
#
#  conv2d_2 (Conv2D)           (None, 71, 1, 50)         12550
#
#  batch_normalization_1 (Batc  (None, 71, 1, 50)        200
#  hNormalization)
#
#  activation_1 (Activation)   (None, 71, 1, 50)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 1, 50)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 23, 1, 50)         0
#
#  permute_1 (Permute)         (None, 23, 50, 1)         0
#
#  reshape_1 (Reshape)         (None, 23, 50)            0
#
#  lstm (LSTM)                 (None, 23, 32)            10624
#
#  lstm_1 (LSTM)               (None, 23, 32)            8320
#
#  flatten (Flatten)           (None, 736)               0
#
#  dense (Dense)               (None, 4)                 2948
#
# =================================================================
# Total params: 48,792
# Trainable params: 48,642
# Non-trainable params: 150
# _________________________________________________________________
# None

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])
history = model.fit(X_train_valid_prep, y_train_valid_prep, batch_size=64, epochs=500,callbacks=callbacks,
                    validation_split=0.2, verbose=1)
# Out:
# Epoch 1/500
# 106/106 [==============================] - 19s 41ms/step - loss: 1.3240 - acc: 0.3540 - val_loss: 1.1949 - val_acc: 0.4574 - lr: 0.0010
# Epoch 2/500
# 106/106 [==============================] - 2s 23ms/step - loss: 1.1622 - acc: 0.4833 - val_loss: 1.0485 - val_acc: 0.5591 - lr: 0.0010
# Epoch 3/500
# 106/106 [==============================] - 3s 24ms/step - loss: 1.0789 - acc: 0.5380 - val_loss: 0.9940 - val_acc: 0.5881 - lr: 0.0010
# Epoch 4/500
# 106/106 [==============================] - 3s 24ms/step - loss: 1.0175 - acc: 0.5725 - val_loss: 0.8782 - val_acc: 0.6430 - lr: 0.0010
# Epoch 5/500
# 106/106 [==============================] - 3s 24ms/step - loss: 0.9709 - acc: 0.5972 - val_loss: 0.8308 - val_acc: 0.6673 - lr: 0.0010
# Epoch 6/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.9206 - acc: 0.6186 - val_loss: 0.7941 - val_acc: 0.6838 - lr: 0.0010
# Epoch 7/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.8816 - acc: 0.6478 - val_loss: 0.7214 - val_acc: 0.7264 - lr: 0.0010
# Epoch 8/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.8315 - acc: 0.6696 - val_loss: 0.6564 - val_acc: 0.7518 - lr: 0.0010
# Epoch 9/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.7816 - acc: 0.6955 - val_loss: 0.6856 - val_acc: 0.7287 - lr: 0.0010
# Epoch 10/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.7579 - acc: 0.7040 - val_loss: 0.5913 - val_acc: 0.7825 - lr: 0.0010
# Epoch 11/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.7373 - acc: 0.7095 - val_loss: 0.5298 - val_acc: 0.8044 - lr: 0.0010
# Epoch 12/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.6841 - acc: 0.7329 - val_loss: 0.5355 - val_acc: 0.7943 - lr: 0.0010
# Epoch 13/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.6642 - acc: 0.7402 - val_loss: 0.4831 - val_acc: 0.8274 - lr: 0.0010
# Epoch 14/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.6329 - acc: 0.7552 - val_loss: 0.4793 - val_acc: 0.8203 - lr: 0.0010
# Epoch 15/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.6161 - acc: 0.7578 - val_loss: 0.4196 - val_acc: 0.8517 - lr: 0.0010
# Epoch 16/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.6005 - acc: 0.7637 - val_loss: 0.4176 - val_acc: 0.8522 - lr: 0.0010
# Epoch 17/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.5645 - acc: 0.7754 - val_loss: 0.4149 - val_acc: 0.8481 - lr: 0.0010
# Epoch 18/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.5593 - acc: 0.7863 - val_loss: 0.3911 - val_acc: 0.8552 - lr: 0.0010
# Epoch 19/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.5317 - acc: 0.7993 - val_loss: 0.3311 - val_acc: 0.8877 - lr: 0.0010
# Epoch 20/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.5112 - acc: 0.8048 - val_loss: 0.3275 - val_acc: 0.8883 - lr: 0.0010
# Epoch 21/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.4909 - acc: 0.8067 - val_loss: 0.3030 - val_acc: 0.9013 - lr: 0.0010
# Epoch 22/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.4711 - acc: 0.8199 - val_loss: 0.2794 - val_acc: 0.9102 - lr: 0.0010
# Epoch 23/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.4582 - acc: 0.8257 - val_loss: 0.2727 - val_acc: 0.9137 - lr: 0.0010
# Epoch 24/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.4310 - acc: 0.8385 - val_loss: 0.2618 - val_acc: 0.9072 - lr: 0.0010
# Epoch 25/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.4452 - acc: 0.8285 - val_loss: 0.2262 - val_acc: 0.9297 - lr: 0.0010
# Epoch 26/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.4097 - acc: 0.8418 - val_loss: 0.2488 - val_acc: 0.9161 - lr: 0.0010
# Epoch 27/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.4119 - acc: 0.8477 - val_loss: 0.2166 - val_acc: 0.9362 - lr: 0.0010
# Epoch 28/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.3980 - acc: 0.8505 - val_loss: 0.2065 - val_acc: 0.9391 - lr: 0.0010
# Epoch 29/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.3806 - acc: 0.8598 - val_loss: 0.1735 - val_acc: 0.9551 - lr: 0.0010
# Epoch 30/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.3701 - acc: 0.8602 - val_loss: 0.1941 - val_acc: 0.9433 - lr: 0.0010
# Epoch 31/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.3558 - acc: 0.8704 - val_loss: 0.1703 - val_acc: 0.9492 - lr: 0.0010
# Epoch 32/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.3343 - acc: 0.8746 - val_loss: 0.1467 - val_acc: 0.9610 - lr: 0.0010
# Epoch 33/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.3386 - acc: 0.8744 - val_loss: 0.2045 - val_acc: 0.9362 - lr: 0.0010
# Epoch 34/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.3193 - acc: 0.8836 - val_loss: 0.1502 - val_acc: 0.9622 - lr: 0.0010
# Epoch 35/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.3323 - acc: 0.8746 - val_loss: 0.1807 - val_acc: 0.9433 - lr: 0.0010
# Epoch 36/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.3250 - acc: 0.8771 - val_loss: 0.1388 - val_acc: 0.9622 - lr: 0.0010
# Epoch 37/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2927 - acc: 0.8920 - val_loss: 0.1225 - val_acc: 0.9681 - lr: 0.0010
# Epoch 38/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2974 - acc: 0.8904 - val_loss: 0.1151 - val_acc: 0.9663 - lr: 0.0010
# Epoch 39/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2786 - acc: 0.9006 - val_loss: 0.1076 - val_acc: 0.9746 - lr: 0.0010
# Epoch 40/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2746 - acc: 0.8994 - val_loss: 0.0950 - val_acc: 0.9793 - lr: 0.0010
# Epoch 41/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2950 - acc: 0.8899 - val_loss: 0.1486 - val_acc: 0.9551 - lr: 0.0010
# Epoch 42/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2798 - acc: 0.8960 - val_loss: 0.0918 - val_acc: 0.9793 - lr: 0.0010
# Epoch 43/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2590 - acc: 0.9026 - val_loss: 0.0843 - val_acc: 0.9811 - lr: 0.0010
# Epoch 44/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2491 - acc: 0.9060 - val_loss: 0.0751 - val_acc: 0.9835 - lr: 0.0010
# Epoch 45/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2284 - acc: 0.9137 - val_loss: 0.0858 - val_acc: 0.9781 - lr: 0.0010
# Epoch 46/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2551 - acc: 0.9048 - val_loss: 0.0809 - val_acc: 0.9781 - lr: 0.0010
# Epoch 47/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2382 - acc: 0.9167 - val_loss: 0.0731 - val_acc: 0.9840 - lr: 0.0010
# Epoch 48/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2287 - acc: 0.9164 - val_loss: 0.0599 - val_acc: 0.9911 - lr: 0.0010
# Epoch 49/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2278 - acc: 0.9152 - val_loss: 0.0636 - val_acc: 0.9888 - lr: 0.0010
# Epoch 50/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2175 - acc: 0.9233 - val_loss: 0.0673 - val_acc: 0.9858 - lr: 0.0010
# Epoch 51/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2284 - acc: 0.9168 - val_loss: 0.0585 - val_acc: 0.9882 - lr: 0.0010
# Epoch 52/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2185 - acc: 0.9193 - val_loss: 0.0647 - val_acc: 0.9858 - lr: 0.0010
# Epoch 53/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2130 - acc: 0.9220 - val_loss: 0.0545 - val_acc: 0.9876 - lr: 0.0010
# Epoch 54/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2093 - acc: 0.9218 - val_loss: 0.0465 - val_acc: 0.9905 - lr: 0.0010
# Epoch 55/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2130 - acc: 0.9243 - val_loss: 0.0518 - val_acc: 0.9882 - lr: 0.0010
# Epoch 56/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2026 - acc: 0.9283 - val_loss: 0.0671 - val_acc: 0.9823 - lr: 0.0010
# Epoch 57/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.1923 - acc: 0.9286 - val_loss: 0.0681 - val_acc: 0.9811 - lr: 0.0010
# Epoch 58/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.1959 - acc: 0.9300 - val_loss: 0.0383 - val_acc: 0.9941 - lr: 0.0010
# Epoch 59/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.1881 - acc: 0.9311 - val_loss: 0.0388 - val_acc: 0.9935 - lr: 0.0010
# Epoch 60/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.1864 - acc: 0.9317 - val_loss: 0.0441 - val_acc: 0.9935 - lr: 0.0010
# Epoch 61/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.1843 - acc: 0.9325 - val_loss: 0.0387 - val_acc: 0.9929 - lr: 0.0010
# Epoch 62/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.1672 - acc: 0.9394 - val_loss: 0.0328 - val_acc: 0.9953 - lr: 0.0010
# Epoch 63/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.1762 - acc: 0.9356 - val_loss: 0.0381 - val_acc: 0.9917 - lr: 0.0010
# Epoch 64/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.1726 - acc: 0.9388 - val_loss: 0.0313 - val_acc: 0.9965 - lr: 0.0010
# Epoch 65/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.1822 - acc: 0.9338 - val_loss: 0.0435 - val_acc: 0.9905 - lr: 0.0010
# Epoch 66/500
# 106/106 [==============================] - 3s 25ms/step - loss: 0.1689 - acc: 0.9393 - val_loss: 0.0470 - val_acc: 0.9888 - lr: 0.0010
# Epoch 67/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.1671 - acc: 0.9403 - val_loss: 0.0336 - val_acc: 0.9965 - lr: 0.0010
# Epoch 68/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1670 - acc: 0.9409 - val_loss: 0.0338 - val_acc: 0.9929 - lr: 0.0010
# Epoch 69/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1664 - acc: 0.9394 - val_loss: 0.0360 - val_acc: 0.9911 - lr: 0.0010
# Epoch 70/500
# 106/106 [==============================] - 3s 28ms/step - loss: 0.1705 - acc: 0.9391 - val_loss: 0.0298 - val_acc: 0.9959 - lr: 0.0010
# Epoch 71/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1663 - acc: 0.9381 - val_loss: 0.0288 - val_acc: 0.9970 - lr: 0.0010
# Epoch 72/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1478 - acc: 0.9501 - val_loss: 0.0315 - val_acc: 0.9941 - lr: 0.0010
# Epoch 73/500
# 106/106 [==============================] - 3s 28ms/step - loss: 0.1466 - acc: 0.9481 - val_loss: 0.0246 - val_acc: 0.9965 - lr: 0.0010
# Epoch 74/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1624 - acc: 0.9400 - val_loss: 0.0251 - val_acc: 0.9976 - lr: 0.0010
# Epoch 75/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1724 - acc: 0.9374 - val_loss: 0.0285 - val_acc: 0.9935 - lr: 0.0010
# Epoch 76/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1397 - acc: 0.9524 - val_loss: 0.0232 - val_acc: 0.9976 - lr: 0.0010
# Epoch 77/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1473 - acc: 0.9470 - val_loss: 0.0241 - val_acc: 0.9970 - lr: 0.0010
# Epoch 78/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1330 - acc: 0.9508 - val_loss: 0.0348 - val_acc: 0.9923 - lr: 0.0010
# Epoch 79/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1406 - acc: 0.9509 - val_loss: 0.0222 - val_acc: 0.9970 - lr: 0.0010
# Epoch 80/500
# 106/106 [==============================] - 3s 28ms/step - loss: 0.1352 - acc: 0.9529 - val_loss: 0.0190 - val_acc: 0.9982 - lr: 0.0010
# Epoch 81/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1452 - acc: 0.9504 - val_loss: 0.0163 - val_acc: 0.9982 - lr: 0.0010
# Epoch 82/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1444 - acc: 0.9489 - val_loss: 0.0271 - val_acc: 0.9947 - lr: 0.0010
# Epoch 83/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.1398 - acc: 0.9502 - val_loss: 0.0181 - val_acc: 0.9982 - lr: 0.0010
# Epoch 84/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1384 - acc: 0.9514 - val_loss: 0.0204 - val_acc: 0.9976 - lr: 0.0010
# Epoch 85/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1385 - acc: 0.9514 - val_loss: 0.0175 - val_acc: 0.9970 - lr: 0.0010
# Epoch 86/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1293 - acc: 0.9554 - val_loss: 0.0137 - val_acc: 0.9994 - lr: 0.0010
# Epoch 87/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1266 - acc: 0.9572 - val_loss: 0.0142 - val_acc: 0.9988 - lr: 0.0010
# Epoch 88/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1245 - acc: 0.9548 - val_loss: 0.0183 - val_acc: 0.9965 - lr: 0.0010
# Epoch 89/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1264 - acc: 0.9574 - val_loss: 0.0164 - val_acc: 0.9976 - lr: 0.0010
# Epoch 90/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1319 - acc: 0.9518 - val_loss: 0.0199 - val_acc: 0.9959 - lr: 0.0010
# Epoch 91/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1179 - acc: 0.9574 - val_loss: 0.0159 - val_acc: 0.9982 - lr: 0.0010
# Epoch 92/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1115 - acc: 0.9603 - val_loss: 0.0247 - val_acc: 0.9959 - lr: 0.0010
# Epoch 93/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1293 - acc: 0.9536 - val_loss: 0.0159 - val_acc: 1.0000 - lr: 0.0010
# Epoch 94/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1372 - acc: 0.9518 - val_loss: 0.0140 - val_acc: 0.9982 - lr: 0.0010
# Epoch 95/500
# 106/106 [==============================] - 3s 28ms/step - loss: 0.1291 - acc: 0.9532 - val_loss: 0.0134 - val_acc: 0.9988 - lr: 0.0010
# Epoch 96/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1305 - acc: 0.9538 - val_loss: 0.0133 - val_acc: 0.9982 - lr: 0.0010
# Epoch 97/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1175 - acc: 0.9573 - val_loss: 0.0158 - val_acc: 0.9970 - lr: 0.0010
# Epoch 98/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.1160 - acc: 0.9583 - val_loss: 0.0151 - val_acc: 0.9982 - lr: 0.0010
# Epoch 99/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1196 - acc: 0.9591 - val_loss: 0.0154 - val_acc: 0.9976 - lr: 0.0010
# Epoch 100/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1093 - acc: 0.9605 - val_loss: 0.0098 - val_acc: 0.9994 - lr: 0.0010
# Epoch 101/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.1114 - acc: 0.9600 - val_loss: 0.0100 - val_acc: 0.9994 - lr: 0.0010
# Epoch 102/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0998 - acc: 0.9654 - val_loss: 0.0088 - val_acc: 0.9994 - lr: 0.0010
# Epoch 103/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1013 - acc: 0.9654 - val_loss: 0.0108 - val_acc: 0.9994 - lr: 0.0010
# Epoch 104/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1126 - acc: 0.9588 - val_loss: 0.0144 - val_acc: 0.9976 - lr: 0.0010
# Epoch 105/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1077 - acc: 0.9626 - val_loss: 0.0099 - val_acc: 0.9994 - lr: 0.0010
# Epoch 106/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1202 - acc: 0.9566 - val_loss: 0.0159 - val_acc: 0.9970 - lr: 0.0010
# Epoch 107/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1059 - acc: 0.9645 - val_loss: 0.0112 - val_acc: 0.9994 - lr: 0.0010
# Epoch 108/500
# 106/106 [==============================] - 3s 28ms/step - loss: 0.1089 - acc: 0.9631 - val_loss: 0.0123 - val_acc: 0.9976 - lr: 0.0010
# Epoch 109/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1125 - acc: 0.9595 - val_loss: 0.0140 - val_acc: 0.9965 - lr: 0.0010
# Epoch 110/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1067 - acc: 0.9619 - val_loss: 0.0119 - val_acc: 0.9982 - lr: 0.0010
# Epoch 111/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0973 - acc: 0.9671 - val_loss: 0.0102 - val_acc: 0.9994 - lr: 0.0010
# Epoch 112/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0999 - acc: 0.9639 - val_loss: 0.0090 - val_acc: 0.9994 - lr: 0.0010
# Epoch 113/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0968 - acc: 0.9662 - val_loss: 0.0109 - val_acc: 0.9982 - lr: 0.0010
# Epoch 114/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1086 - acc: 0.9614 - val_loss: 0.0094 - val_acc: 0.9982 - lr: 0.0010
# Epoch 115/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1031 - acc: 0.9644 - val_loss: 0.0216 - val_acc: 0.9941 - lr: 0.0010
# Epoch 116/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1058 - acc: 0.9617 - val_loss: 0.0070 - val_acc: 0.9994 - lr: 0.0010
# Epoch 117/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0974 - acc: 0.9656 - val_loss: 0.0130 - val_acc: 0.9976 - lr: 0.0010
# Epoch 118/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1086 - acc: 0.9600 - val_loss: 0.0079 - val_acc: 0.9994 - lr: 0.0010
# Epoch 119/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0915 - acc: 0.9696 - val_loss: 0.0077 - val_acc: 0.9994 - lr: 0.0010
# Epoch 120/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0834 - acc: 0.9688 - val_loss: 0.0084 - val_acc: 1.0000 - lr: 0.0010
# Epoch 121/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0825 - acc: 0.9733 - val_loss: 0.0072 - val_acc: 0.9994 - lr: 0.0010
# Epoch 122/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1020 - acc: 0.9644 - val_loss: 0.0069 - val_acc: 0.9982 - lr: 0.0010
# Epoch 123/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0893 - acc: 0.9685 - val_loss: 0.0079 - val_acc: 0.9982 - lr: 0.0010
# Epoch 124/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0843 - acc: 0.9712 - val_loss: 0.0094 - val_acc: 0.9982 - lr: 0.0010
# Epoch 125/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0986 - acc: 0.9659 - val_loss: 0.0083 - val_acc: 0.9988 - lr: 0.0010
# Epoch 126/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0901 - acc: 0.9687 - val_loss: 0.0092 - val_acc: 0.9982 - lr: 0.0010
# Epoch 127/500
# 106/106 [==============================] - 3s 28ms/step - loss: 0.0862 - acc: 0.9704 - val_loss: 0.0059 - val_acc: 0.9994 - lr: 0.0010
# Epoch 128/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0943 - acc: 0.9651 - val_loss: 0.0065 - val_acc: 0.9994 - lr: 0.0010
# Epoch 129/500
# 106/106 [==============================] - 3s 28ms/step - loss: 0.0955 - acc: 0.9668 - val_loss: 0.0054 - val_acc: 0.9994 - lr: 0.0010
# Epoch 130/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0787 - acc: 0.9737 - val_loss: 0.0052 - val_acc: 0.9994 - lr: 0.0010
# Epoch 131/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0794 - acc: 0.9727 - val_loss: 0.0072 - val_acc: 0.9988 - lr: 0.0010
# Epoch 132/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.1022 - acc: 0.9632 - val_loss: 0.0091 - val_acc: 0.9982 - lr: 0.0010
# Epoch 133/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0906 - acc: 0.9685 - val_loss: 0.0055 - val_acc: 0.9994 - lr: 0.0010
# Epoch 134/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0826 - acc: 0.9706 - val_loss: 0.0066 - val_acc: 0.9988 - lr: 0.0010
# Epoch 135/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0828 - acc: 0.9713 - val_loss: 0.0062 - val_acc: 0.9994 - lr: 0.0010
# Epoch 136/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0858 - acc: 0.9682 - val_loss: 0.0080 - val_acc: 0.9982 - lr: 0.0010
# Epoch 137/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0826 - acc: 0.9721 - val_loss: 0.0084 - val_acc: 0.9982 - lr: 0.0010
# Epoch 138/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0927 - acc: 0.9660 - val_loss: 0.0052 - val_acc: 0.9994 - lr: 0.0010
# Epoch 139/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0848 - acc: 0.9725 - val_loss: 0.0073 - val_acc: 0.9988 - lr: 0.0010
# Epoch 140/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0875 - acc: 0.9684 - val_loss: 0.0056 - val_acc: 0.9988 - lr: 0.0010
# Epoch 141/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0816 - acc: 0.9716 - val_loss: 0.0059 - val_acc: 0.9988 - lr: 0.0010
# Epoch 142/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0937 - acc: 0.9660 - val_loss: 0.0095 - val_acc: 0.9982 - lr: 0.0010
# Epoch 143/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0793 - acc: 0.9743 - val_loss: 0.0070 - val_acc: 0.9994 - lr: 0.0010
# Epoch 144/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0921 - acc: 0.9678 - val_loss: 0.0091 - val_acc: 0.9988 - lr: 0.0010
# Epoch 145/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0779 - acc: 0.9756 - val_loss: 0.0056 - val_acc: 1.0000 - lr: 0.0010
# Epoch 146/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0915 - acc: 0.9668 - val_loss: 0.0053 - val_acc: 1.0000 - lr: 0.0010
# Epoch 147/500
# 106/106 [==============================] - 3s 28ms/step - loss: 0.0746 - acc: 0.9761 - val_loss: 0.0044 - val_acc: 1.0000 - lr: 0.0010
# Epoch 148/500
# 106/106 [==============================] - 3s 28ms/step - loss: 0.0816 - acc: 0.9703 - val_loss: 0.0038 - val_acc: 1.0000 - lr: 0.0010
# Epoch 149/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0777 - acc: 0.9718 - val_loss: 0.0048 - val_acc: 0.9988 - lr: 0.0010
# Epoch 150/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0750 - acc: 0.9730 - val_loss: 0.0042 - val_acc: 1.0000 - lr: 0.0010
# Epoch 151/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0725 - acc: 0.9736 - val_loss: 0.0048 - val_acc: 0.9988 - lr: 0.0010
# Epoch 152/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.0774 - acc: 0.9755 - val_loss: 0.0051 - val_acc: 0.9988 - lr: 0.0010
# Epoch 153/500
# 106/106 [==============================] - 3s 28ms/step - loss: 0.0710 - acc: 0.9764 - val_loss: 0.0026 - val_acc: 1.0000 - lr: 0.0010
# Epoch 154/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0700 - acc: 0.9758 - val_loss: 0.0056 - val_acc: 1.0000 - lr: 0.0010
# Epoch 155/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0757 - acc: 0.9752 - val_loss: 0.0079 - val_acc: 0.9994 - lr: 0.0010
# Epoch 156/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0888 - acc: 0.9687 - val_loss: 0.0038 - val_acc: 0.9994 - lr: 0.0010
# Epoch 157/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0798 - acc: 0.9718 - val_loss: 0.0030 - val_acc: 1.0000 - lr: 0.0010
# Epoch 158/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0721 - acc: 0.9765 - val_loss: 0.0044 - val_acc: 0.9994 - lr: 0.0010
# Epoch 159/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0752 - acc: 0.9734 - val_loss: 0.0040 - val_acc: 0.9994 - lr: 0.0010
# Epoch 160/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0710 - acc: 0.9747 - val_loss: 0.0063 - val_acc: 0.9994 - lr: 0.0010
# Epoch 161/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0783 - acc: 0.9740 - val_loss: 0.0043 - val_acc: 0.9994 - lr: 0.0010
# Epoch 162/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0773 - acc: 0.9730 - val_loss: 0.0051 - val_acc: 0.9994 - lr: 0.0010
# Epoch 163/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0748 - acc: 0.9759 - val_loss: 0.0039 - val_acc: 1.0000 - lr: 0.0010
# Epoch 164/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0762 - acc: 0.9709 - val_loss: 0.0038 - val_acc: 1.0000 - lr: 0.0010
# Epoch 165/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0660 - acc: 0.9761 - val_loss: 0.0039 - val_acc: 1.0000 - lr: 0.0010
# Epoch 166/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0728 - acc: 0.9753 - val_loss: 0.0046 - val_acc: 1.0000 - lr: 0.0010
# Epoch 167/500
# 106/106 [==============================] - 3s 26ms/step - loss: 0.0669 - acc: 0.9781 - val_loss: 0.0039 - val_acc: 0.9994 - lr: 0.0010
# Epoch 168/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0639 - acc: 0.9777 - val_loss: 0.0037 - val_acc: 1.0000 - lr: 0.0010
# Epoch 169/500
# 106/106 [==============================] - 3s 27ms/step - loss: 0.0797 - acc: 0.9727 - val_loss: 0.0057 - val_acc: 0.9988 - lr: 0.0010
# Epoch 170/500
# 106/106 [==============================] - 3s 28ms/step - loss: 0.0755 - acc: 0.9738 - val_loss: 0.0038 - val_acc: 0.9994 - lr: 0.0010
# Epoch 171/500
# 106/106 [==============================] - 3s 29ms/step - loss: 0.0773 - acc: 0.9733 - val_loss: 0.0032 - val_acc: 1.0000 - lr: 0.0010
# Epoch 172/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0678 - acc: 0.9765 - val_loss: 0.0046 - val_acc: 0.9994 - lr: 0.0010
# Epoch 173/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0683 - acc: 0.9762 - val_loss: 0.0046 - val_acc: 0.9994 - lr: 0.0010
# Epoch 174/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0552 - acc: 0.9818 - val_loss: 0.0019 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 175/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0456 - acc: 0.9854 - val_loss: 0.0026 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 176/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0447 - acc: 0.9849 - val_loss: 0.0035 - val_acc: 0.9988 - lr: 5.0000e-04
# Epoch 177/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0505 - acc: 0.9833 - val_loss: 0.0019 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 178/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0481 - acc: 0.9848 - val_loss: 0.0018 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 179/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0470 - acc: 0.9843 - val_loss: 0.0024 - val_acc: 0.9994 - lr: 5.0000e-04
# Epoch 180/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0457 - acc: 0.9843 - val_loss: 0.0016 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 181/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0512 - acc: 0.9845 - val_loss: 0.0021 - val_acc: 0.9994 - lr: 5.0000e-04
# Epoch 182/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0474 - acc: 0.9849 - val_loss: 0.0015 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 183/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0417 - acc: 0.9871 - val_loss: 0.0018 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 184/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0460 - acc: 0.9845 - val_loss: 0.0021 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 185/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0495 - acc: 0.9843 - val_loss: 0.0012 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 186/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0440 - acc: 0.9855 - val_loss: 0.0014 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 187/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0408 - acc: 0.9868 - val_loss: 0.0012 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 188/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0463 - acc: 0.9839 - val_loss: 0.0022 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 189/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0456 - acc: 0.9849 - val_loss: 0.0019 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 190/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0409 - acc: 0.9855 - val_loss: 0.0014 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 191/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0448 - acc: 0.9854 - val_loss: 0.0015 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 192/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0510 - acc: 0.9824 - val_loss: 0.0013 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 193/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0476 - acc: 0.9806 - val_loss: 0.0014 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 194/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0414 - acc: 0.9871 - val_loss: 0.0013 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 195/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0433 - acc: 0.9846 - val_loss: 0.0014 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 196/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0445 - acc: 0.9852 - val_loss: 0.0014 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 197/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0450 - acc: 0.9848 - val_loss: 0.0012 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 198/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0415 - acc: 0.9855 - val_loss: 0.0011 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 199/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0398 - acc: 0.9868 - val_loss: 9.8143e-04 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 200/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0430 - acc: 0.9849 - val_loss: 0.0016 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 201/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0367 - acc: 0.9871 - val_loss: 0.0013 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 202/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0415 - acc: 0.9854 - val_loss: 0.0013 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 203/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0436 - acc: 0.9849 - val_loss: 0.0016 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 204/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0424 - acc: 0.9863 - val_loss: 0.0021 - val_acc: 0.9994 - lr: 5.0000e-04
# Epoch 205/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0402 - acc: 0.9866 - val_loss: 0.0012 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 206/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0370 - acc: 0.9870 - val_loss: 0.0019 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 207/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0387 - acc: 0.9870 - val_loss: 0.0014 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 208/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0429 - acc: 0.9845 - val_loss: 0.0014 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 209/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0421 - acc: 0.9861 - val_loss: 0.0019 - val_acc: 0.9994 - lr: 5.0000e-04
# Epoch 210/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0374 - acc: 0.9868 - val_loss: 0.0011 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 211/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0441 - acc: 0.9851 - val_loss: 0.0012 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 212/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0436 - acc: 0.9851 - val_loss: 0.0021 - val_acc: 0.9994 - lr: 5.0000e-04
# Epoch 213/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0339 - acc: 0.9897 - val_loss: 0.0019 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 214/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0351 - acc: 0.9874 - val_loss: 0.0018 - val_acc: 0.9994 - lr: 5.0000e-04
# Epoch 215/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0480 - acc: 0.9836 - val_loss: 0.0040 - val_acc: 0.9982 - lr: 5.0000e-04
# Epoch 216/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0433 - acc: 0.9845 - val_loss: 0.0030 - val_acc: 0.9988 - lr: 5.0000e-04
# Epoch 217/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0425 - acc: 0.9861 - val_loss: 0.0022 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 218/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0380 - acc: 0.9876 - val_loss: 0.0017 - val_acc: 1.0000 - lr: 5.0000e-04
# Epoch 219/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0373 - acc: 0.9873 - val_loss: 0.0017 - val_acc: 0.9994 - lr: 5.0000e-04
# Epoch 220/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0356 - acc: 0.9898 - val_loss: 0.0025 - val_acc: 0.9994 - lr: 2.5000e-04
# Epoch 221/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0333 - acc: 0.9885 - val_loss: 0.0011 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 222/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0379 - acc: 0.9864 - val_loss: 0.0014 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 223/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0326 - acc: 0.9895 - val_loss: 0.0010 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 224/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0275 - acc: 0.9914 - val_loss: 0.0012 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 225/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0314 - acc: 0.9902 - val_loss: 8.7663e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 226/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0288 - acc: 0.9922 - val_loss: 9.2186e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 227/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0255 - acc: 0.9931 - val_loss: 0.0010 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 228/500
# 106/106 [==============================] - 3s 32ms/step - loss: 0.0311 - acc: 0.9898 - val_loss: 7.7042e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 229/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0275 - acc: 0.9907 - val_loss: 8.2738e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 230/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0294 - acc: 0.9905 - val_loss: 8.3035e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 231/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0288 - acc: 0.9897 - val_loss: 6.6201e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 232/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0300 - acc: 0.9907 - val_loss: 7.0281e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 233/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0299 - acc: 0.9908 - val_loss: 9.9260e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 234/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0240 - acc: 0.9920 - val_loss: 6.3716e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 235/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0234 - acc: 0.9928 - val_loss: 7.4642e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 236/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0364 - acc: 0.9888 - val_loss: 8.4633e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 237/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0249 - acc: 0.9923 - val_loss: 0.0013 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 238/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0268 - acc: 0.9917 - val_loss: 9.0186e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 239/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0290 - acc: 0.9910 - val_loss: 7.4804e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 240/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0288 - acc: 0.9904 - val_loss: 8.8449e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 241/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0278 - acc: 0.9908 - val_loss: 9.9167e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 242/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0281 - acc: 0.9907 - val_loss: 8.6753e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 243/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0253 - acc: 0.9925 - val_loss: 9.4702e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 244/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0289 - acc: 0.9905 - val_loss: 8.3101e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 245/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0286 - acc: 0.9907 - val_loss: 6.9233e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 246/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0300 - acc: 0.9901 - val_loss: 5.8422e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 247/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0246 - acc: 0.9910 - val_loss: 4.9151e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 248/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0291 - acc: 0.9898 - val_loss: 5.2965e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 249/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0262 - acc: 0.9914 - val_loss: 5.5588e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 250/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0333 - acc: 0.9889 - val_loss: 5.0713e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 251/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0293 - acc: 0.9908 - val_loss: 5.4206e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 252/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0269 - acc: 0.9920 - val_loss: 4.0107e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 253/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0237 - acc: 0.9926 - val_loss: 5.9248e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 254/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0272 - acc: 0.9916 - val_loss: 3.9946e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 255/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0265 - acc: 0.9913 - val_loss: 4.4512e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 256/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0295 - acc: 0.9901 - val_loss: 7.5776e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 257/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0312 - acc: 0.9904 - val_loss: 6.2496e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 258/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0307 - acc: 0.9888 - val_loss: 6.4167e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 259/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0295 - acc: 0.9908 - val_loss: 6.9592e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 260/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0301 - acc: 0.9895 - val_loss: 5.2450e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 261/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0258 - acc: 0.9911 - val_loss: 5.4886e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 262/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0289 - acc: 0.9911 - val_loss: 5.8428e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 263/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0305 - acc: 0.9900 - val_loss: 5.2467e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 264/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0256 - acc: 0.9922 - val_loss: 4.3858e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 265/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0291 - acc: 0.9914 - val_loss: 5.8035e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 266/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0257 - acc: 0.9920 - val_loss: 5.0921e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 267/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0296 - acc: 0.9911 - val_loss: 5.8033e-04 - val_acc: 1.0000 - lr: 2.5000e-04
# Epoch 268/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0230 - acc: 0.9931 - val_loss: 3.6927e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 269/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0226 - acc: 0.9932 - val_loss: 3.4039e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 270/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0264 - acc: 0.9910 - val_loss: 3.2344e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 271/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0247 - acc: 0.9929 - val_loss: 3.6587e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 272/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0256 - acc: 0.9919 - val_loss: 3.5025e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 273/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0225 - acc: 0.9938 - val_loss: 2.9904e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 274/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0260 - acc: 0.9911 - val_loss: 3.5125e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 275/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0272 - acc: 0.9911 - val_loss: 3.2258e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 276/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0232 - acc: 0.9928 - val_loss: 3.5213e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 277/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0241 - acc: 0.9914 - val_loss: 3.7029e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 278/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0220 - acc: 0.9928 - val_loss: 3.4879e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 279/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0290 - acc: 0.9911 - val_loss: 4.1096e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 280/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0227 - acc: 0.9928 - val_loss: 3.9749e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 281/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0238 - acc: 0.9914 - val_loss: 3.5100e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 282/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0250 - acc: 0.9923 - val_loss: 3.9819e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 283/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0249 - acc: 0.9925 - val_loss: 3.9599e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 284/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0202 - acc: 0.9935 - val_loss: 4.0588e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 285/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0252 - acc: 0.9926 - val_loss: 3.9946e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 286/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0298 - acc: 0.9904 - val_loss: 5.2125e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 287/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0261 - acc: 0.9907 - val_loss: 4.0890e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 288/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0267 - acc: 0.9910 - val_loss: 3.5139e-04 - val_acc: 1.0000 - lr: 1.2500e-04
# Epoch 289/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0209 - acc: 0.9938 - val_loss: 3.9131e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 290/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0268 - acc: 0.9914 - val_loss: 3.8884e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 291/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0242 - acc: 0.9926 - val_loss: 5.1605e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 292/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0208 - acc: 0.9936 - val_loss: 3.9342e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 293/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0213 - acc: 0.9929 - val_loss: 3.8930e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 294/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0270 - acc: 0.9901 - val_loss: 4.6809e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 295/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0220 - acc: 0.9922 - val_loss: 4.0911e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 296/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0177 - acc: 0.9948 - val_loss: 4.2352e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 297/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0204 - acc: 0.9935 - val_loss: 4.0665e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 298/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0202 - acc: 0.9938 - val_loss: 3.9422e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 299/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0246 - acc: 0.9931 - val_loss: 3.9283e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 300/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0195 - acc: 0.9938 - val_loss: 3.8380e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 301/500
# 106/106 [==============================] - 3s 32ms/step - loss: 0.0236 - acc: 0.9935 - val_loss: 3.8424e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 302/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0249 - acc: 0.9922 - val_loss: 4.1096e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 303/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0176 - acc: 0.9947 - val_loss: 4.4042e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 304/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0258 - acc: 0.9913 - val_loss: 4.4936e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 305/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0239 - acc: 0.9925 - val_loss: 4.1161e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 306/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0269 - acc: 0.9902 - val_loss: 4.1977e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 307/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0227 - acc: 0.9925 - val_loss: 4.1907e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 308/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0212 - acc: 0.9932 - val_loss: 4.8859e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 309/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0268 - acc: 0.9902 - val_loss: 5.0259e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 310/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0216 - acc: 0.9932 - val_loss: 4.0122e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 311/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0236 - acc: 0.9929 - val_loss: 3.5682e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 312/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0231 - acc: 0.9932 - val_loss: 3.5044e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 313/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0193 - acc: 0.9936 - val_loss: 3.9030e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 314/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0218 - acc: 0.9935 - val_loss: 3.2273e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 315/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0237 - acc: 0.9922 - val_loss: 3.3595e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 316/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0209 - acc: 0.9929 - val_loss: 2.9120e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 317/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0194 - acc: 0.9936 - val_loss: 3.6497e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 318/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0178 - acc: 0.9947 - val_loss: 3.3122e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 319/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0226 - acc: 0.9925 - val_loss: 4.2490e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 320/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0206 - acc: 0.9936 - val_loss: 3.8835e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 321/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0204 - acc: 0.9932 - val_loss: 3.9043e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 322/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0241 - acc: 0.9923 - val_loss: 3.9760e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 323/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0163 - acc: 0.9950 - val_loss: 4.3758e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 324/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0246 - acc: 0.9922 - val_loss: 3.4244e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 325/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0225 - acc: 0.9905 - val_loss: 3.8038e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 326/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0239 - acc: 0.9932 - val_loss: 3.8753e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 327/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0235 - acc: 0.9917 - val_loss: 3.7802e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 328/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0184 - acc: 0.9944 - val_loss: 3.8743e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 329/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0262 - acc: 0.9916 - val_loss: 3.9855e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 330/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0215 - acc: 0.9922 - val_loss: 3.4267e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 331/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0215 - acc: 0.9934 - val_loss: 3.2657e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 332/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0214 - acc: 0.9936 - val_loss: 3.5800e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 333/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0210 - acc: 0.9939 - val_loss: 3.3689e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 334/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0181 - acc: 0.9944 - val_loss: 3.5854e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 335/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0222 - acc: 0.9934 - val_loss: 4.0084e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 336/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0195 - acc: 0.9941 - val_loss: 4.3732e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 337/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0249 - acc: 0.9928 - val_loss: 4.0053e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 338/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0198 - acc: 0.9931 - val_loss: 3.4427e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 339/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0229 - acc: 0.9932 - val_loss: 3.5533e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 340/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0193 - acc: 0.9944 - val_loss: 3.8489e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 341/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0210 - acc: 0.9939 - val_loss: 4.3546e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 342/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0202 - acc: 0.9934 - val_loss: 4.5349e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 343/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0207 - acc: 0.9931 - val_loss: 4.4360e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 344/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0189 - acc: 0.9941 - val_loss: 4.8487e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 345/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0209 - acc: 0.9945 - val_loss: 4.8491e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 346/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0220 - acc: 0.9936 - val_loss: 4.0685e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 347/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0232 - acc: 0.9929 - val_loss: 3.5511e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 348/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0215 - acc: 0.9923 - val_loss: 3.9024e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 349/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0201 - acc: 0.9931 - val_loss: 3.6152e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 350/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0205 - acc: 0.9941 - val_loss: 3.2139e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 351/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0192 - acc: 0.9941 - val_loss: 4.0398e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 352/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0196 - acc: 0.9947 - val_loss: 3.5537e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 353/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0220 - acc: 0.9928 - val_loss: 3.5852e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 354/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0212 - acc: 0.9931 - val_loss: 4.0176e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 355/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0207 - acc: 0.9945 - val_loss: 3.9973e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 356/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0204 - acc: 0.9947 - val_loss: 4.1795e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 357/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0210 - acc: 0.9931 - val_loss: 3.8286e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 358/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0239 - acc: 0.9922 - val_loss: 4.5648e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 359/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0213 - acc: 0.9928 - val_loss: 4.6681e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 360/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0215 - acc: 0.9938 - val_loss: 3.9392e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 361/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0220 - acc: 0.9928 - val_loss: 3.6743e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 362/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0201 - acc: 0.9941 - val_loss: 4.3282e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 363/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0177 - acc: 0.9947 - val_loss: 4.1849e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 364/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0219 - acc: 0.9928 - val_loss: 4.3947e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 365/500
# 106/106 [==============================] - 3s 31ms/step - loss: 0.0173 - acc: 0.9951 - val_loss: 5.0457e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 366/500
# 106/106 [==============================] - 3s 30ms/step - loss: 0.0241 - acc: 0.9925 - val_loss: 4.5963e-04 - val_acc: 1.0000 - lr: 1.0000e-04
# Epoch 366: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(X_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 14/14 [==============================] - 1s 10ms/step - loss: 1.9283 - acc: 0.6591
# Test accuracy 0.6591421961784363
# Test loss 1.9283422231674194

# %%
plt.plot(history.history['acc'], label='train')
plt.plot(history.history['val_acc'], label='test')
plt.legend();
